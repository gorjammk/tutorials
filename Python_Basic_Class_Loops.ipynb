# %% [markdown]
# # If statements
# - We can use if statements to conditionally do some calculation. The conditions are defined by the words if, elif (which stands for else if) and else. We can have as many elif statements as we want. The indented code below each condition is the code that will execute if the condition is True.
# ![image.png](attachment:image.png)

# %%
#In the example, a if code block is created which executes only when the variable i is divisible by 3.
i = 15
if i % 3 == 0:
    print(i," is divisible by 3.")
# Out:
# 15  is divisible by 3.

# %% [markdown]
# # If-else Statement
# The else statement is always used with if statement. It is used to execute block of codes whenever if condition gives false result.
# ![image.png](attachment:image.png)

# %%
#In the example, else statement is used to print a message if the variable i is not divisible by 3.

i = 16
if i % 3 == 0:
  print(i," is divisible by 3.")
else:
  print(i," is not divisible by 3.")
# Out:
# 16  is not divisible by 3.

# %%
# If statement
x = 1
if x < 1:
    score = 'low'
elif x <= 4: # elif = else if
    score = 'medium'
else:
    score = 'high'
print (score)
# Out:
# medium

# %%
# If statement with a boolean
x = True
if x:
    print ("worked")
# Out:
# worked

# %% [markdown]
# # For Loops
# The for loop in Python is used to iterate over a given sequence and executes a set of statements for each element in the sequence. A sequence can be any data structure like list, tuple, set, string, dictionary and range iterables etc.
# ![image.png](attachment:image.png)

# %%
#For loop over a range:In the example, for loop is used over a given range.
print("#Result 1:")
for i in range(4):
  print(i, i * 2)

print("\n#Result 2:")
for j in range(2, 6):
  print(j, j ** 2)

print("\n#Result 3:")
#for k in range(10, 2, -2)  
for k in range(0, 12, 2):
  print(k)
# Out:
# #Result 1:
# 0 0
# 1 2
# 2 4
# 3 6
#
# #Result 2:
# 2 4
# 3 9
# 4 16
# 5 25
#
# #Result 3:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
#for loop
data=[1, 8, 6, 3, 4]
for data_points in data:
    print (data_points)
# Out:
# 1
# 8
# 6
# 3
# 4

# %%
#For loop over List In the example, for loop is used over a list to access its elements.

veggies = ["carrots", "broccoli", "beans"]
for number_veg in veggies:
    print (number_veg)
# Out:
# carrots
# broccoli
# beans

# %%
#For loop over Tuple In the example, for loop is used over a tuple to access its elements.

days = ('Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday')
for day in days:
    print(day)
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
#For loop over String As discussed earlier, a for loop can be used to access characters of a given string.

word = 'python'
for letter in word:
    print(letter)
# Out:
# p
# y
# t
# h
# o
# n

# %%
#For loop over Dictionary In the same way, a for loop can be used to access key-value pairs of a given dictionary.

dict = {
  'year': '2000',
  'month': 'March',
  'date': 15
}

print("#Result 1:")
for day in dict:
    print(day)

print("\n#Result 2:")
for day, value in dict.items():
    print(day,value)
# Out:
# #Result 1:
# year
# month
# date
#
# #Result 2:
# year 2000
# month March
# date 15

# %%
#When the loop encounters the break command, the loop will terminate immediately. If there were more items in the list, they will not be processed.

color = ['red', 'blue', 'green', 'yellow', 'black', 'white'] 
for x in color:
    if(x == 'yellow'):
        print("Getting out of the loop.")
        break
    print(x)
# Out:
# red
# blue
# green
# Getting out of the loop.

# %%
#Break statement with Nested loop
#In the example below, break statement terminates the inner loop whenever multiplier becomes 100.
# nested loop without break statement	
digits = [1, 2, 3] 
multipliers = [10, 100, 1000]
print("# nested loop without break statement")
for digit in digits:
    for multiplier in multipliers:
        print (digit * multiplier)
# Out:
# # nested loop without break statement
# 10
# 100
# 1000
# 20
# 200
# 2000
# 30
# 300
# 3000

# %%
# nested loop with break statement  
digits = [1, 2, 3] 
multipliers = [10, 100, 1000]
print("# nested loop with break statement")
for digit in digits:
    for multiplier in multipliers:
        if (multiplier == 100):
            break
        print (digit * multiplier)
# Out:
# # nested loop with break statement
# 10
# 20
# 30

# %% [markdown]
# # Continue statement with For loop
# In the example below, continue statement is used to skip the for loop if the value of variable x becomes 'yellow'.

# %%
color = ['red', 'blue', 'green', 'yellow', 'black', 'white']
for x in color:
    if(x == 'yellow'):
        print('this iteration is skipped.')
        continue
    print(x)
# Out:
# red
# blue
# green
# this iteration is skipped.
# black
# white

# %% [markdown]
# # Continue statement with Nested loop
# The continue statement skip the inner loop's block of codes whenever condition is fulfilled. In below mentioned example, program skips the inner loop for multiplier = 100.

# %%
# nested loop without continue statement   
digits = [1, 2, 3] 
multipliers = [10, 100, 1000]
print("# nested loop without continue statement")
for digit in digits:
    for multiplier in multipliers:
        print (digit * multiplier)
# Out:
# # nested loop without continue statement
# 10
# 100
# 1000
# 20
# 200
# 2000
# 30
# 300
# 3000

# %%
# nested loop with continue statement  
digits = [1, 2, 3] 
multipliers = [10, 100, 1000]
print("# nested loop with continue statement")
for digit in digits:
    for multiplier in multipliers:
        if (multiplier == 100):
            continue
        print (digit * multiplier)
# Out:
# # nested loop with continue statement
# 10
# 1000
# 20
# 2000
# 30
# 3000

# %% [markdown]
# # The While Loop
# The While loop allows a set of statements to be executed repeatedly as long as a specified condition is true. It can be viewed as a repeating if statement. A while loop is preferred over for loop whenever number of iteration is not known beforehand.
# ![image.png](attachment:image.png)

# %%
#In below mentioned example, program uses while loop to sum all integers from 1 to 5.
sum = 0
i = 1
while (i < 6):
    sum = sum + i
    i = i+1
print(sum)
# Out:
# 15

# %% [markdown]
# # While loop with else statement
# The else block can be used with while loop also. The else block is executed when condition check in while loop returns false.

# %%
i = 1
while (i < 6):
    print(i)
    i = i + 1
else:
    print('loop exhausted.')
# Out:
# 1
# 2
# 3
# 4
# 5
# loop exhausted.

# %% [markdown]
# However, when program exits from while loop using break statements, it ignores the else block.

# %%
i = 1
while (i < 6):
    print(i)
    i = i + 1
    if (i==4):
        break
else:
  print('loop exhausted.')
# Out:
# 1
# 2
# 3

# %% [markdown]
# # Break statement with While loop
# In the example below, break statement is used to get out of the while loop if the value of variable j becomes 4.

# %%
j=1
while (j < 10):
    if (j == 4):
        print("Getting out of the loop.")
        break
    print(j)
    j = j + 1
# Out:
# 1
# 2
# 3
# Getting out of the loop.

# %%
# nested loop without break statement	
digits = [1, 2, 3] 
multipliers = [10, 100, 1000]
print("# nested loop without break statement")
for digit in digits:
    for multiplier in multipliers:
        print (digit * multiplier)
# Out:
# # nested loop without break statement
# 10
# 100
# 1000
# 20
# 200
# 2000
# 30
# 300
# 3000

# %%
# nested loop with break statement  
digits = [1, 2, 3] 
multipliers = [10, 100, 1000]
print("# nested loop with break statement")
for digit in digits:
    for multiplier in multipliers:
        if (multiplier == 100):
            break
        print (digit * multiplier)
# Out:
# # nested loop with break statement
# 10
# 20
# 30
