# %%
import pandas as pd
import xarray as xr

# %% [markdown]
# # This below commands convert your ncfile into CSV file

# %%
nc = xr.open_dataset('DATA_Drive/PhD-Work/Python_Scripts/Classes-Taken-By-Me/Python_Class_AU/Pre-DATA.nc')
nc  # read nc file
# Out:
# <xarray.Dataset>
# Dimensions:    (lat: 73, lon: 144, time: 72, nbnds: 2)
# Coordinates:
#   * lat        (lat) float32 90.0 87.5 85.0 82.5 ... -82.5 -85.0 -87.5 -90.0
#   * lon        (lon) float32 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * time       (time) datetime64[ns] 2015-01-01 2015-02-01 ... 2020-12-01
# Dimensions without coordinates: nbnds
# Data variables:
#     pres       (time, lat, lon) float32 ...
#     time_bnds  (time, nbnds) datetime64[ns] ...
# Attributes:
#     Conventions:    CF-1.0
#     title:          Monthly NCEP/DOE Reanalysis 2
#     comments:       Data is from \nNCEP/DOE AMIP-II Reanalysis (Reanalysis-2)...
#     platform:       Model
#     source:         NCEP/DOE AMIP-II Reanalysis (Reanalysis-2) Model
#     institution:    National Centers for Environmental Prediction
#     dataset_title:  NCEP-DOE AMIP-II Reanalysis
#     References:     https://www.psl.noaa.gov/data/gridded/data.ncep.reanalysi...
# ...

# %%
nc.pres.to_dataframe().to_csv('precip.csv') # this will convert you xarray into csv format

# %% [markdown]
# # you can take the same CSV file and convert it into ncfile using following commands

# %%
df = pd.read_csv('precip.csv') #read the csv file
df
# Out:
#               time   lat    lon       pres
# 0       2015-01-01  90.0    0.0  101730.00
# 1       2015-01-01  90.0    2.5  101730.00
# 2       2015-01-01  90.0    5.0  101730.00
# 3       2015-01-01  90.0    7.5  101730.00
# 4       2015-01-01  90.0   10.0  101730.00
# ...            ...   ...    ...        ...
# 756859  2020-12-01 -90.0  347.5   69765.56
# 756860  2020-12-01 -90.0  350.0   69765.56
# 756861  2020-12-01 -90.0  352.5   69765.56
# 756862  2020-12-01 -90.0  355.0   69765.56
# 756863  2020-12-01 -90.0  357.5   69765.56
#
# [756864 rows x 4 columns]

# %%
df = df.set_index(["time", "lon", "lat"])  #indexing time ,lat, lon 
df
# Out:
#                              pres
# time       lon   lat
# 2015-01-01 0.0    90.0  101730.00
#            2.5    90.0  101730.00
#            5.0    90.0  101730.00
#            7.5    90.0  101730.00
#            10.0   90.0  101730.00
# ...                           ...
# 2020-12-01 347.5 -90.0   69765.56
#            350.0 -90.0   69765.56
#            352.5 -90.0   69765.56
#            355.0 -90.0   69765.56
#            357.5 -90.0   69765.56
#
# [756864 rows x 1 columns]

# %%
xr = df.to_xarray() # this will convert your pandas dataframe to xarray

# %%
xr
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 72, lon: 144, lat: 73)
# Coordinates:
#   * time     (time) object '2015-01-01' '2015-02-01' ... '2020-12-01'
#   * lon      (lon) float64 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * lat      (lat) float64 -90.0 -87.5 -85.0 -82.5 -80.0 ... 82.5 85.0 87.5 90.0
# Data variables:
#     pres     (time, lon, lat) float64 7.028e+04 6.96e+04 ... 1.027e+05 1.025e+05

# %%
#nc=xr.to_netcdf('my_netcdf.nc')  # you can save xarray into netcdf file using this

# %%
nc=xr.to_netcdf # it will write you xarray into netcdf format

# %%
nc
# Out:
# <bound method Dataset.to_netcdf of <xarray.Dataset>
# Dimensions:  (time: 72, lon: 144, lat: 73)
# Coordinates:
#   * time     (time) object '2015-01-01' '2015-02-01' ... '2020-12-01'
#   * lon      (lon) float64 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * lat      (lat) float64 -90.0 -87.5 -85.0 -82.5 -80.0 ... 82.5 85.0 87.5 90.0
# Data variables:
#     pres     (time, lon, lat) float64 7.028e+04 6.96e+04 ... 1.027e+05 1.025e+05>
